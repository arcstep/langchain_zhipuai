# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
import os
os.chdir('..')
print(os.getcwd())
# Out:
# /Users/xuehongwei/github/langchain_zhipuai

# %% [markdown]
# # Embedding

# %%
from langchain_zhipu import ZhipuAIEmbeddings

# %%
emb = ZhipuAIEmbeddings()

# %%
v = emb.embed_documents(["我的名字是小明", "我8岁了"])

# %%
v
# Out:
# [[-0.053591880947351456,
#   -0.01696884259581566,
#   -0.018346531316637993,
#   0.025541584938764572,
#   0.028896687552332878,
#   -0.0022674668580293655,
#   -0.043790046125650406,
#   0.004647635854780674,
#   -0.0026024277321994305,
#   0.03366570919752121,
#   0.01057006698101759,
#   0.03373122960329056,
#   -0.02362598292529583,
#   -0.01192311942577362,
#   0.011338801123201847,
#   -0.008601438254117966,
#   0.028698647394776344,
#   0.02649521827697754,
#   -0.05472227931022644,
#   -0.056775350123643875,
#   -0.08053073287010193,
#   0.028051229193806648,
#   -0.002832222729921341,
#   0.0067673795856535435,
#   0.05662504583597183,
#   -0.018723025918006897,
#   0.03040160983800888,
#   0.016986362636089325,
#   -0.039999429136514664,
#   -0.04047761857509613,
#   0.035811252892017365,
#   -0.04312403127551079,
#   0.004147446248680353,
#   -0.02919750288128853,
#   0.029223067685961723,
#   0.005120342597365379,
#   0.0394415445625782,
#   0.017064180225133896,
# ...
